# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
from collections import Counter
from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BTC Models/BTC-Hourly.csv')
data = data.iloc[::-1].reset_index(drop=True)
data.index = data.index + 1

# %%
data.head()
# Out:
#          unix                 date   symbol     open     high      low  \
# 1  1526364000  2018-05-15 06:00:00  BTC/USD  8733.86  8796.68  8707.28
# 2  1526367600  2018-05-15 07:00:00  BTC/USD  8740.99  8766.00  8721.11
# 3  1526371200  2018-05-15 08:00:00  BTC/USD  8739.00  8750.27  8660.53
# 4  1526374800  2018-05-15 09:00:00  BTC/USD  8728.49  8754.40  8701.35
# 5  1526378400  2018-05-15 10:00:00  BTC/USD  8708.32  8865.00  8695.11
#
#      close   Volume BTC  Volume USD
# 1  8740.99   4906603.14      559.93
# 2  8739.00   2390398.89      273.58
# 3  8728.49   7986062.84      917.79
# 4  8708.32   1593991.98      182.62
# 5  8795.90  11101273.74     1260.69

# %%
open_prices = list(data["open"])
close_prices = list(data["close"])

# %%
class TradeBot:
  def __init__(self, open_prices, model, window_length, expected_percentage_return, expected_trade_duration, sequence_length):
    split = int(len(open_prices)*0.7)
    self.prices_open_train = open_prices[:split]
    self.prices_open_test = open_prices[split:]
    self.model = model
    self.window_length = window_length
    self.expected_percentage_return = expected_percentage_return
    self.expected_trade_duration = expected_trade_duration
    self.sequence_length = sequence_length

  @staticmethod
  def max_min_index_finder(data, l):
    assert l%2 == 1, "code breaks down if l is even"
    index = [0]
    for i in range(l,len(data)+1):
      curl = data[i-l:i]
      if curl.index(max(curl)) == (l-1)/2:
        index.append((2*i-l+1)//2)
      if curl.index(min(curl)) == (l-1)/2:
        index.append((2*i-l+1)//2)
    return index

  @staticmethod
  def data_checkpoints(prices_open, percent, l, n, ind):
    d = int(n/2)
    checkpoints = {}
    for i in ind[:-4]:
      if prices_open[i+d+l]-prices_open[i+d]>prices_open[i+d]*percent/100:
        checkpoints[i] = 1
      else:
        checkpoints[i] = 0
    return checkpoints

  @staticmethod
  def make_data(w_and_b_l, l, ind, checkpoints):
    X_data = []
    y_data = []
    for i in range(l,len(w_and_b_l)-3):
      X_data.append(w_and_b_l[i-l:i])
      y_data.append(checkpoints[ind[i]])
    return np.array(X_data), np.array(y_data)

  @staticmethod
  def split_fit(data, index):
    y_pred = []
    model = LinearRegression()
    w_and_b_l = []
    for i in range(1,len(index)):
      if index[i-1]!=index[i]:
        X = np.array(range(0,index[i]-index[i-1])).reshape(-1,1)
        y = np.array(data[index[i-1]:index[i]])
        model.fit(X,y)
        y_temp = model.predict(X)
        for j in range(len(y_temp)):
          y_pred.append(y_temp[j])
        w_and_b_l.append([model.coef_[0],index[i]-index[i-1]])
    return np.array(y_pred), w_and_b_l

  def train(self, loss, optimizer, metrics, epochs, save_best_model = False):
    self.min_max_indices = TradeBot.max_min_index_finder(self.prices_open_train, self.window_length)
    self.fit_lines, self.w_and_b_l = TradeBot.split_fit(self.prices_open_train, self.min_max_indices)
    self.scaler = StandardScaler()
    self.w_and_b_l_normalized = self.scaler.fit_transform(self.w_and_b_l)
    self.checkpoints = TradeBot.data_checkpoints(self.prices_open_train, self.expected_percentage_return, self.expected_trade_duration, self.window_length, self.min_max_indices)
    self.X_data, self.y_data = TradeBot.make_data(self.w_and_b_l_normalized, self.sequence_length, self.min_max_indices, self.checkpoints)

    q_80 = int(len(self.X_data) * .8)
    q_90 = int(len(self.y_data) * .9)

    self.X_train, self.y_train = np.array(self.X_data[:q_80]), np.array(self.y_data[:q_80])
    self.X_val, self.y_val = np.array(self.X_data[q_80:q_90]), np.array(self.y_data[q_80:q_90])
    self.X_test, self.y_test = np.array(self.X_data[q_90:]), np.array(self.y_data[q_90:])

    if save_best_model:
      checkpoint_callback = ModelCheckpoint(filepath='best_model.h5',
                                        monitor='val_loss',
                                        save_best_only=True)

      self.model.compile(loss=loss,
                        optimizer=optimizer,
                        metrics=metrics)
      self.model.fit(self.X_train, self.y_train, validation_data=(self.X_val, self.y_val), epochs = epochs, callbacks=[checkpoint_callback])

      self.model = tf.keras.models.load_model('best_model.h5')

    else:
      self.model.compile(loss=loss,
                        optimizer=optimizer,
                        metrics=metrics)
      self.model.fit(self.X_train, self.y_train, validation_data=(self.X_val, self.y_val), epochs = epochs)
      self.model.save('model')

  def test(self, test_probability_threshold):
    self.test_probability_threshold = test_probability_threshold
    self.test_probability_predictions = self.model.predict(self.X_test)
    self.test_predictions = self.test_probability_predictions>self.test_probability_threshold
    self.test_predictions.reshape(self.test_predictions.shape[0],)
    self.zero_misclassifications = 0
    self.one_misclassifications = 0
    self.total_ones_predicted = np.sum(self.test_predictions==1)
    for i in range(self.test_probability_predictions.shape[0]):
      if self.test_predictions[i]==1 and self.y_test[i]==0:
        self.zero_misclassifications+=1
      if self.test_predictions[i]==0 and self.y_test[i]==1:
        self.one_misclassifications+=1
    self.total_misclassifications = self.one_misclassifications + self.zero_misclassifications
    self.accuracy = 1 - self.total_misclassifications/self.y_test.shape[0]
    print(f'test size:{self.y_test.shape[0]}')
    print(f'number of ones predicted:{self.total_ones_predicted}')
    print(f'number of zeros misclassified as ones:{self.zero_misclassifications}')
    print(f'number of ones misclassifies as zeros:{self.one_misclassifications}')
    print(f'total number of misclassifications:{self.total_misclassifications}')
    print(f'accuracy:{self.accuracy}')

  @staticmethod
  def backtest_make_data(w_and_b_l, l, ind):
    X_data = []
    y_data = []
    for i in range(l,len(w_and_b_l)-3):
      X_data.append(w_and_b_l[i-l:i])
    return np.array(X_data)

  def backtest(self, stop_loss_percent, take_profit_percent, backtest_probability_threshold, window_length):
    self.backtest_window_length = window_length
    self.backtest_probability_threshold = backtest_probability_threshold
    self.backtest_indices = TradeBot.max_min_index_finder(self.prices_open_test, self.backtest_window_length)
    self.backtest_fit_lines, self.backtest_w_and_b_l = TradeBot.split_fit(self.prices_open_test, self.backtest_indices)
    self.backtest_scaler = StandardScaler()
    self.backtest_w_and_b_l_normalized = self.backtest_scaler.fit_transform(self.backtest_w_and_b_l)
    self.backtest_X_data = TradeBot.backtest_make_data(self.backtest_w_and_b_l_normalized, self.sequence_length, self.backtest_indices)

    tpf = take_profit_percent/100
    slf = -stop_loss_percent/100

    i = self.sequence_length
    n = int(self.backtest_window_length/2)

    self.total_profit = 0
    self.trade_history = []
    self.backtest_predictions = self.model.predict(self.backtest_X_data)
    while i<len(self.backtest_indices)-200:
      buy_price = None
      sell_price = None
      profit = None
      intoTrade = False
      current_prediction = self.backtest_predictions[i-self.backtest_window_length]
      if current_prediction > self.backtest_probability_threshold:
        intoTrade = True
        j = self.backtest_indices[i]
        buy_price = self.prices_open_test[j+n]*current_prediction
        while buy_price*slf<(self.prices_open_test[j+n]*current_prediction-buy_price)<buy_price*tpf:
          j+=1
        sell_price = self.prices_open_test[j+n]*current_prediction
        profit = sell_price-buy_price
        self.total_profit+=profit
        self.trade_history.append(profit)
        while self.backtest_indices[i]<j:
          i+=1
      print(f"interation:{i-10}, intoTrade:{intoTrade}, prediction:{current_prediction}, buyPrice:{buy_price}, sellPrice:{sell_price}, profit:{profit}")
      i+=1
    return self.total_profit, self.trade_history

# %%
model1 = tf.keras.Sequential([
    layers.Input((7, 2)),
    layers.LSTM(64, return_sequences = True),
    layers.LSTM(64),# LSTM layer after the Dense layer
    layers.Dense(32, activation='relu'),
    layers.Dense(32, activation='relu'),
    # Add more LSTM layers if needed
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer, adjust activation as needed
])

# %%
trade_bot = TradeBot(open_prices, model1, 23, 2.5, 35, 7)

# %%
trade_bot.train(tf.keras.losses.BinaryCrossentropy(), Adam(learning_rate=0.01), ['mean_absolute_error'], 40)
# Out:
# Epoch 1/40
# 36/36 [==============================] - 7s 42ms/step - loss: 0.1671 - mean_absolute_error: 0.0694 - val_loss: 0.7632 - val_mean_absolute_error: 0.2364
# Epoch 2/40
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.0485 - val_loss: 1.1910 - val_mean_absolute_error: 0.2571
# Epoch 3/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0651 - mean_absolute_error: 0.0319 - val_loss: 1.8832 - val_mean_absolute_error: 0.2774
# Epoch 4/40
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0340 - mean_absolute_error: 0.0138 - val_loss: 2.4929 - val_mean_absolute_error: 0.2976
# Epoch 5/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0995 - mean_absolute_error: 0.0398 - val_loss: 1.0590 - val_mean_absolute_error: 0.2588
# Epoch 6/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0683 - mean_absolute_error: 0.0374 - val_loss: 1.3786 - val_mean_absolute_error: 0.2322
# Epoch 7/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0605 - mean_absolute_error: 0.0329 - val_loss: 1.4544 - val_mean_absolute_error: 0.2423
# Epoch 8/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0277 - mean_absolute_error: 0.0147 - val_loss: 2.1190 - val_mean_absolute_error: 0.2523
# Epoch 9/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0159 - mean_absolute_error: 0.0065 - val_loss: 2.4434 - val_mean_absolute_error: 0.2583
# Epoch 10/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0200 - mean_absolute_error: 0.0090 - val_loss: 2.2154 - val_mean_absolute_error: 0.2697
# Epoch 11/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0712 - mean_absolute_error: 0.0268 - val_loss: 1.4578 - val_mean_absolute_error: 0.2425
# Epoch 12/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0286 - mean_absolute_error: 0.0149 - val_loss: 2.1959 - val_mean_absolute_error: 0.3056
# Epoch 13/40
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0064 - mean_absolute_error: 0.0051 - val_loss: 2.3208 - val_mean_absolute_error: 0.2879
# Epoch 14/40
# 36/36 [==============================] - 0s 12ms/step - loss: 6.4273e-04 - mean_absolute_error: 6.3317e-04 - val_loss: 2.8175 - val_mean_absolute_error: 0.2918
# Epoch 15/40
# 36/36 [==============================] - 0s 14ms/step - loss: 2.0409e-04 - mean_absolute_error: 2.0377e-04 - val_loss: 3.0602 - val_mean_absolute_error: 0.2898
# Epoch 16/40
# 36/36 [==============================] - 0s 12ms/step - loss: 1.2672e-04 - mean_absolute_error: 1.2660e-04 - val_loss: 3.1780 - val_mean_absolute_error: 0.2861
# Epoch 17/40
# 36/36 [==============================] - 0s 12ms/step - loss: 8.9778e-05 - mean_absolute_error: 8.9719e-05 - val_loss: 3.2963 - val_mean_absolute_error: 0.2841
# Epoch 18/40
# 36/36 [==============================] - 1s 14ms/step - loss: 6.9107e-05 - mean_absolute_error: 6.9070e-05 - val_loss: 3.3760 - val_mean_absolute_error: 0.2816
# Epoch 19/40
# 36/36 [==============================] - 1s 17ms/step - loss: 5.5432e-05 - mean_absolute_error: 5.5407e-05 - val_loss: 3.4437 - val_mean_absolute_error: 0.2795
# Epoch 20/40
# 36/36 [==============================] - 1s 19ms/step - loss: 4.5584e-05 - mean_absolute_error: 4.5568e-05 - val_loss: 3.5018 - val_mean_absolute_error: 0.2774
# Epoch 21/40
# 36/36 [==============================] - 1s 21ms/step - loss: 3.8685e-05 - mean_absolute_error: 3.8672e-05 - val_loss: 3.5605 - val_mean_absolute_error: 0.2758
# Epoch 22/40
# 36/36 [==============================] - 1s 20ms/step - loss: 3.3018e-05 - mean_absolute_error: 3.3009e-05 - val_loss: 3.6111 - val_mean_absolute_error: 0.2747
# Epoch 23/40
# 36/36 [==============================] - 1s 21ms/step - loss: 2.8746e-05 - mean_absolute_error: 2.8739e-05 - val_loss: 3.6549 - val_mean_absolute_error: 0.2737
# Epoch 24/40
# 36/36 [==============================] - 1s 16ms/step - loss: 2.5307e-05 - mean_absolute_error: 2.5301e-05 - val_loss: 3.6964 - val_mean_absolute_error: 0.2726
# Epoch 25/40
# 36/36 [==============================] - 0s 12ms/step - loss: 2.2371e-05 - mean_absolute_error: 2.2366e-05 - val_loss: 3.7314 - val_mean_absolute_error: 0.2717
# Epoch 26/40
# 36/36 [==============================] - 0s 12ms/step - loss: 2.0061e-05 - mean_absolute_error: 2.0057e-05 - val_loss: 3.7734 - val_mean_absolute_error: 0.2712
# Epoch 27/40
# 36/36 [==============================] - 0s 12ms/step - loss: 1.8076e-05 - mean_absolute_error: 1.8073e-05 - val_loss: 3.8066 - val_mean_absolute_error: 0.2705
# Epoch 28/40
# 36/36 [==============================] - 0s 12ms/step - loss: 1.6375e-05 - mean_absolute_error: 1.6373e-05 - val_loss: 3.8341 - val_mean_absolute_error: 0.2698
# Epoch 29/40
# 36/36 [==============================] - 0s 14ms/step - loss: 1.4914e-05 - mean_absolute_error: 1.4912e-05 - val_loss: 3.8633 - val_mean_absolute_error: 0.2692
# Epoch 30/40
# 36/36 [==============================] - 0s 12ms/step - loss: 1.3666e-05 - mean_absolute_error: 1.3664e-05 - val_loss: 3.9000 - val_mean_absolute_error: 0.2688
# Epoch 31/40
# 36/36 [==============================] - 0s 13ms/step - loss: 1.2518e-05 - mean_absolute_error: 1.2516e-05 - val_loss: 3.9259 - val_mean_absolute_error: 0.2684
# Epoch 32/40
# 36/36 [==============================] - 0s 12ms/step - loss: 1.1550e-05 - mean_absolute_error: 1.1549e-05 - val_loss: 3.9553 - val_mean_absolute_error: 0.2680
# Epoch 33/40
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0687e-05 - mean_absolute_error: 1.0685e-05 - val_loss: 3.9795 - val_mean_absolute_error: 0.2675
# Epoch 34/40
# 36/36 [==============================] - 0s 12ms/step - loss: 9.9100e-06 - mean_absolute_error: 9.9089e-06 - val_loss: 4.0055 - val_mean_absolute_error: 0.2671
# Epoch 35/40
# 36/36 [==============================] - 0s 13ms/step - loss: 9.2333e-06 - mean_absolute_error: 9.2320e-06 - val_loss: 4.0301 - val_mean_absolute_error: 0.2667
# Epoch 36/40
# 36/36 [==============================] - 0s 12ms/step - loss: 8.6060e-06 - mean_absolute_error: 8.6050e-06 - val_loss: 4.0533 - val_mean_absolute_error: 0.2664
# Epoch 37/40
# 36/36 [==============================] - 0s 13ms/step - loss: 8.0359e-06 - mean_absolute_error: 8.0349e-06 - val_loss: 4.0755 - val_mean_absolute_error: 0.2660
# Epoch 38/40
# 36/36 [==============================] - 0s 14ms/step - loss: 7.5229e-06 - mean_absolute_error: 7.5223e-06 - val_loss: 4.0946 - val_mean_absolute_error: 0.2655
# Epoch 39/40
# 36/36 [==============================] - 0s 12ms/step - loss: 7.0633e-06 - mean_absolute_error: 7.0626e-06 - val_loss: 4.1177 - val_mean_absolute_error: 0.2653
# Epoch 40/40
# 36/36 [==============================] - 0s 13ms/step - loss: 6.6434e-06 - mean_absolute_error: 6.6428e-06 - val_loss: 4.1356 - val_mean_absolute_error: 0.2648

# %%
trade_bot.test(0.5)
# Out:
# 5/5 [==============================] - 1s 5ms/step
# test size:142
# number of ones predicted:27
# number of zeros misclassified as ones:20
# number of ones misclassifies as zeros:50
# total number of misclassifications:70
# accuracy:0.5070422535211268

# %%
total_profit, trade_history = trade_bot.backtest(1, 2, 0.5, 23)
# Out:
# 19/19 [==============================] - 0s 5ms/step
# interation:-3, intoTrade:False, prediction:[0.00010337], buyPrice:None, sellPrice:None, profit:None
# interation:-2, intoTrade:False, prediction:[8.5727916e-05], buyPrice:None, sellPrice:None, profit:None
# interation:-1, intoTrade:False, prediction:[0.00041102], buyPrice:None, sellPrice:None, profit:None
# interation:0, intoTrade:False, prediction:[0.4092542], buyPrice:None, sellPrice:None, profit:None
# interation:1, intoTrade:False, prediction:[1.4898095e-13], buyPrice:None, sellPrice:None, profit:None
# interation:2, intoTrade:False, prediction:[1.4493571e-12], buyPrice:None, sellPrice:None, profit:None
# interation:3, intoTrade:False, prediction:[4.486501e-09], buyPrice:None, sellPrice:None, profit:None
# interation:4, intoTrade:False, prediction:[5.4044704e-06], buyPrice:None, sellPrice:None, profit:None
# interation:5, intoTrade:False, prediction:[0.00229224], buyPrice:None, sellPrice:None, profit:None
# interation:6, intoTrade:False, prediction:[0.00095395], buyPrice:None, sellPrice:None, profit:None
# interation:7, intoTrade:False, prediction:[3.8854716e-07], buyPrice:None, sellPrice:None, profit:None
# interation:8, intoTrade:False, prediction:[0.02058868], buyPrice:None, sellPrice:None, profit:None
# interation:10, intoTrade:True, prediction:[0.60798466], buyPrice:[20299.557], sellPrice:[20053.875], profit:[-245.68164]
# interation:11, intoTrade:False, prediction:[1.6372192e-06], buyPrice:None, sellPrice:None, profit:None
# interation:12, intoTrade:False, prediction:[3.0301272e-11], buyPrice:None, sellPrice:None, profit:None
# interation:13, intoTrade:False, prediction:[3.7985113e-09], buyPrice:None, sellPrice:None, profit:None
# interation:14, intoTrade:False, prediction:[4.2850053e-07], buyPrice:None, sellPrice:None, profit:None
# interation:15, intoTrade:False, prediction:[2.4108564e-07], buyPrice:None, sellPrice:None, profit:None
# interation:16, intoTrade:False, prediction:[2.0141629e-06], buyPrice:None, sellPrice:None, profit:None
# interation:17, intoTrade:False, prediction:[8.3712877e-07], buyPrice:None, sellPrice:None, profit:None
# interation:18, intoTrade:False, prediction:[4.0260826e-11], buyPrice:None, sellPrice:None, profit:None
# interation:19, intoTrade:False, prediction:[9.985625e-13], buyPrice:None, sellPrice:None, profit:None
# interation:20, intoTrade:False, prediction:[2.5302212e-11], buyPrice:None, sellPrice:None, profit:None
# interation:21, intoTrade:False, prediction:[8.189525e-06], buyPrice:None, sellPrice:None, profit:None
# interation:22, intoTrade:False, prediction:[0.0057209], buyPrice:None, sellPrice:None, profit:None
# interation:23, intoTrade:False, prediction:[0.00241455], buyPrice:None, sellPrice:None, profit:None
# interation:24, intoTrade:False, prediction:[6.699676e-07], buyPrice:None, sellPrice:None, profit:None
# interation:26, intoTrade:True, prediction:[0.7239736], buyPrice:[34079.414], sellPrice:[33660.355], profit:[-419.0586]
# interation:27, intoTrade:False, prediction:[1.14574504e-11], buyPrice:None, sellPrice:None, profit:None
# interation:28, intoTrade:False, prediction:[7.297817e-08], buyPrice:None, sellPrice:None, profit:None
# interation:29, intoTrade:False, prediction:[0.36506286], buyPrice:None, sellPrice:None, profit:None
# interation:31, intoTrade:True, prediction:[0.9999999], buyPrice:[47925.258], sellPrice:[47065.598], profit:[-859.66016]
# interation:33, intoTrade:True, prediction:[0.8504616], buyPrice:[40078.477], sellPrice:[41631.797], profit:[1553.3203]
# interation:34, intoTrade:False, prediction:[5.2181895e-06], buyPrice:None, sellPrice:None, profit:None
# interation:37, intoTrade:True, prediction:[1.], buyPrice:[49015.], sellPrice:[50614.51], profit:[1599.5117]
# interation:38, intoTrade:False, prediction:[6.0608296e-09], buyPrice:None, sellPrice:None, profit:None
# interation:40, intoTrade:True, prediction:[0.99999356], buyPrice:[51238.5], sellPrice:[52669.5], profit:[1431.]
# interation:42, intoTrade:True, prediction:[0.9998429], buyPrice:[56491.12], sellPrice:[55450.957], profit:[-1040.1641]
# interation:44, intoTrade:True, prediction:[1.], buyPrice:[57561.3], sellPrice:[56287.42], profit:[-1273.8789]
# interation:46, intoTrade:True, prediction:[1.], buyPrice:[52527.15], sellPrice:[51200.44], profit:[-1326.707]
# interation:47, intoTrade:False, prediction:[3.241099e-12], buyPrice:None, sellPrice:None, profit:None
# interation:48, intoTrade:False, prediction:[0.00039896], buyPrice:None, sellPrice:None, profit:None
# interation:49, intoTrade:False, prediction:[2.32628e-08], buyPrice:None, sellPrice:None, profit:None
# interation:50, intoTrade:False, prediction:[1.3444749e-07], buyPrice:None, sellPrice:None, profit:None
# interation:51, intoTrade:False, prediction:[2.956013e-07], buyPrice:None, sellPrice:None, profit:None
# interation:52, intoTrade:False, prediction:[6.020563e-06], buyPrice:None, sellPrice:None, profit:None
# interation:53, intoTrade:False, prediction:[0.27210116], buyPrice:None, sellPrice:None, profit:None
# interation:54, intoTrade:False, prediction:[0.42147312], buyPrice:None, sellPrice:None, profit:None
# interation:55, intoTrade:False, prediction:[0.2825481], buyPrice:None, sellPrice:None, profit:None
# interation:56, intoTrade:False, prediction:[1.1753409e-07], buyPrice:None, sellPrice:None, profit:None
# interation:57, intoTrade:False, prediction:[6.6796044e-16], buyPrice:None, sellPrice:None, profit:None
# interation:58, intoTrade:False, prediction:[4.4805896e-07], buyPrice:None, sellPrice:None, profit:None
# interation:61, intoTrade:True, prediction:[0.9999999], buyPrice:[49717.37], sellPrice:[48442.277], profit:[-1275.0938]
# interation:62, intoTrade:False, prediction:[4.8429767e-12], buyPrice:None, sellPrice:None, profit:None
# interation:63, intoTrade:False, prediction:[2.925008e-08], buyPrice:None, sellPrice:None, profit:None
# interation:64, intoTrade:False, prediction:[2.960684e-06], buyPrice:None, sellPrice:None, profit:None
# interation:66, intoTrade:True, prediction:[0.9999868], buyPrice:[51361.016], sellPrice:[52427.11], profit:[1066.0938]
# interation:68, intoTrade:True, prediction:[0.99999774], buyPrice:[56418.902], sellPrice:[55598.016], profit:[-820.8867]
# interation:69, intoTrade:False, prediction:[1.2797976e-08], buyPrice:None, sellPrice:None, profit:None
# interation:70, intoTrade:False, prediction:[0.01276243], buyPrice:None, sellPrice:None, profit:None
# interation:71, intoTrade:False, prediction:[6.9101556e-09], buyPrice:None, sellPrice:None, profit:None
# interation:73, intoTrade:True, prediction:[1.], buyPrice:[56887.13], sellPrice:[59390.85], profit:[2503.7227]
# interation:74, intoTrade:False, prediction:[1.3159706e-07], buyPrice:None, sellPrice:None, profit:None
# interation:75, intoTrade:False, prediction:[5.177637e-10], buyPrice:None, sellPrice:None, profit:None
# interation:76, intoTrade:False, prediction:[1.8183477e-09], buyPrice:None, sellPrice:None, profit:None
# interation:77, intoTrade:False, prediction:[3.932477e-13], buyPrice:None, sellPrice:None, profit:None
# interation:78, intoTrade:False, prediction:[9.051005e-10], buyPrice:None, sellPrice:None, profit:None
# interation:80, intoTrade:True, prediction:[0.9999998], buyPrice:[57828.24], sellPrice:[59577.008], profit:[1748.7695]
# interation:81, intoTrade:False, prediction:[4.967324e-10], buyPrice:None, sellPrice:None, profit:None
# interation:82, intoTrade:False, prediction:[1.05306305e-10], buyPrice:None, sellPrice:None, profit:None
# interation:84, intoTrade:True, prediction:[1.], buyPrice:[59271.97], sellPrice:[58546.65], profit:[-725.3203]
# interation:85, intoTrade:False, prediction:[0.0002803], buyPrice:None, sellPrice:None, profit:None
# interation:86, intoTrade:False, prediction:[0.05723286], buyPrice:None, sellPrice:None, profit:None
# interation:88, intoTrade:True, prediction:[1.], buyPrice:[57266.22], sellPrice:[56492.98], profit:[-773.2383]
# interation:89, intoTrade:False, prediction:[0.00022114], buyPrice:None, sellPrice:None, profit:None
# interation:90, intoTrade:False, prediction:[9.149326e-15], buyPrice:None, sellPrice:None, profit:None
# interation:91, intoTrade:False, prediction:[7.9986584e-10], buyPrice:None, sellPrice:None, profit:None
# interation:92, intoTrade:False, prediction:[7.5517315e-10], buyPrice:None, sellPrice:None, profit:None
# interation:93, intoTrade:False, prediction:[8.472834e-07], buyPrice:None, sellPrice:None, profit:None
# interation:94, intoTrade:False, prediction:[2.6042555e-09], buyPrice:None, sellPrice:None, profit:None
# interation:95, intoTrade:False, prediction:[1.9161428e-06], buyPrice:None, sellPrice:None, profit:None
# interation:96, intoTrade:False, prediction:[2.359492e-06], buyPrice:None, sellPrice:None, profit:None
# interation:97, intoTrade:False, prediction:[8.6974076e-05], buyPrice:None, sellPrice:None, profit:None
# interation:98, intoTrade:False, prediction:[6.933096e-14], buyPrice:None, sellPrice:None, profit:None
# interation:99, intoTrade:False, prediction:[0.0002845], buyPrice:None, sellPrice:None, profit:None
# interation:100, intoTrade:False, prediction:[0.00177534], buyPrice:None, sellPrice:None, profit:None
# interation:101, intoTrade:False, prediction:[0.03059902], buyPrice:None, sellPrice:None, profit:None
# interation:103, intoTrade:True, prediction:[1.], buyPrice:[59298.34], sellPrice:[58601.17], profit:[-697.16797]
# interation:104, intoTrade:False, prediction:[0.00051864], buyPrice:None, sellPrice:None, profit:None
# interation:105, intoTrade:False, prediction:[2.549885e-08], buyPrice:None, sellPrice:None, profit:None
# interation:106, intoTrade:False, prediction:[0.00216213], buyPrice:None, sellPrice:None, profit:None
# interation:108, intoTrade:True, prediction:[0.99840283], buyPrice:[58982.934], sellPrice:[58150.055], profit:[-832.8789]
# interation:109, intoTrade:False, prediction:[2.8967515e-06], buyPrice:None, sellPrice:None, profit:None
# interation:110, intoTrade:False, prediction:[4.798335e-09], buyPrice:None, sellPrice:None, profit:None
# interation:112, intoTrade:True, prediction:[0.9999965], buyPrice:[58969.363], sellPrice:[58359.883], profit:[-609.48047]
# interation:115, intoTrade:True, prediction:[1.], buyPrice:[56025.], sellPrice:[57465.83], profit:[1440.8281]
# interation:116, intoTrade:False, prediction:[0.00028858], buyPrice:None, sellPrice:None, profit:None
# interation:117, intoTrade:False, prediction:[4.171954e-08], buyPrice:None, sellPrice:None, profit:None
# interation:119, intoTrade:True, prediction:[1.], buyPrice:[59925.99], sellPrice:[59296.1], profit:[-629.8867]
# interation:120, intoTrade:False, prediction:[8.374474e-07], buyPrice:None, sellPrice:None, profit:None
# interation:121, intoTrade:False, prediction:[3.1445248e-14], buyPrice:None, sellPrice:None, profit:None
# interation:122, intoTrade:False, prediction:[6.7313154e-06], buyPrice:None, sellPrice:None, profit:None
# interation:125, intoTrade:True, prediction:[0.9999985], buyPrice:[62954.105], sellPrice:[62167.637], profit:[-786.46875]
# interation:126, intoTrade:False, prediction:[1.0258176e-07], buyPrice:None, sellPrice:None, profit:None
# interation:127, intoTrade:False, prediction:[5.585642e-05], buyPrice:None, sellPrice:None, profit:None
# interation:128, intoTrade:False, prediction:[7.129087e-06], buyPrice:None, sellPrice:None, profit:None
# interation:129, intoTrade:False, prediction:[1.0508651e-08], buyPrice:None, sellPrice:None, profit:None
# interation:130, intoTrade:False, prediction:[9.552234e-11], buyPrice:None, sellPrice:None, profit:None
# interation:131, intoTrade:False, prediction:[0.00020515], buyPrice:None, sellPrice:None, profit:None
# interation:133, intoTrade:True, prediction:[0.9999753], buyPrice:[56322.54], sellPrice:[55681.363], profit:[-641.1758]
# interation:134, intoTrade:False, prediction:[4.3559703e-09], buyPrice:None, sellPrice:None, profit:None
# interation:135, intoTrade:False, prediction:[1.1162319e-15], buyPrice:None, sellPrice:None, profit:None
# interation:136, intoTrade:False, prediction:[2.946829e-09], buyPrice:None, sellPrice:None, profit:None
# interation:137, intoTrade:False, prediction:[0.00499428], buyPrice:None, sellPrice:None, profit:None
# interation:139, intoTrade:True, prediction:[0.9999998], buyPrice:[49109.812], sellPrice:[50264.594], profit:[1154.7812]
# interation:140, intoTrade:False, prediction:[5.9383365e-07], buyPrice:None, sellPrice:None, profit:None
# interation:141, intoTrade:False, prediction:[1.8976385e-05], buyPrice:None, sellPrice:None, profit:None
# interation:142, intoTrade:False, prediction:[0.02401682], buyPrice:None, sellPrice:None, profit:None
# interation:143, intoTrade:False, prediction:[0.00021528], buyPrice:None, sellPrice:None, profit:None
# interation:144, intoTrade:False, prediction:[9.473748e-06], buyPrice:None, sellPrice:None, profit:None
# interation:146, intoTrade:True, prediction:[0.99418676], buyPrice:[54114.28], sellPrice:[53314.79], profit:[-799.4922]
# interation:147, intoTrade:False, prediction:[4.505783e-05], buyPrice:None, sellPrice:None, profit:None
# interation:148, intoTrade:False, prediction:[2.2705698e-10], buyPrice:None, sellPrice:None, profit:None
# interation:152, intoTrade:True, prediction:[0.9928509], buyPrice:[56081.184], sellPrice:[57675.332], profit:[1594.1484]
# interation:154, intoTrade:True, prediction:[1.], buyPrice:[57547.38], sellPrice:[56802.35], profit:[-745.02734]
# interation:155, intoTrade:False, prediction:[0.00025194], buyPrice:None, sellPrice:None, profit:None
# interation:156, intoTrade:False, prediction:[0.02175331], buyPrice:None, sellPrice:None, profit:None
# interation:157, intoTrade:False, prediction:[0.00084023], buyPrice:None, sellPrice:None, profit:None
# interation:158, intoTrade:False, prediction:[8.274778e-12], buyPrice:None, sellPrice:None, profit:None
# interation:159, intoTrade:False, prediction:[2.8893332e-11], buyPrice:None, sellPrice:None, profit:None
# interation:160, intoTrade:False, prediction:[3.528443e-06], buyPrice:None, sellPrice:None, profit:None
# interation:161, intoTrade:False, prediction:[0.00013886], buyPrice:None, sellPrice:None, profit:None
# interation:162, intoTrade:False, prediction:[0.01093001], buyPrice:None, sellPrice:None, profit:None
# interation:163, intoTrade:False, prediction:[9.780405e-10], buyPrice:None, sellPrice:None, profit:None
# interation:164, intoTrade:False, prediction:[0.00051657], buyPrice:None, sellPrice:None, profit:None
# interation:165, intoTrade:False, prediction:[1.6415372e-13], buyPrice:None, sellPrice:None, profit:None
# interation:166, intoTrade:False, prediction:[7.8757806e-13], buyPrice:None, sellPrice:None, profit:None
# interation:167, intoTrade:False, prediction:[7.0458146e-09], buyPrice:None, sellPrice:None, profit:None
# interation:168, intoTrade:False, prediction:[2.073453e-05], buyPrice:None, sellPrice:None, profit:None
# interation:169, intoTrade:False, prediction:[3.7264664e-11], buyPrice:None, sellPrice:None, profit:None
# interation:170, intoTrade:False, prediction:[2.4089847e-12], buyPrice:None, sellPrice:None, profit:None
# interation:171, intoTrade:False, prediction:[6.1749734e-06], buyPrice:None, sellPrice:None, profit:None
# interation:172, intoTrade:False, prediction:[0.08142662], buyPrice:None, sellPrice:None, profit:None
# interation:174, intoTrade:True, prediction:[0.9999998], buyPrice:[45370.203], sellPrice:[44004.004], profit:[-1366.1992]
# interation:175, intoTrade:False, prediction:[1.1634555e-06], buyPrice:None, sellPrice:None, profit:None
# interation:177, intoTrade:True, prediction:[1.], buyPrice:[41842.78], sellPrice:[39385.], profit:[-2457.7812]
# interation:178, intoTrade:False, prediction:[1.1853847e-14], buyPrice:None, sellPrice:None, profit:None
# interation:179, intoTrade:False, prediction:[3.4739905e-08], buyPrice:None, sellPrice:None, profit:None
# interation:180, intoTrade:False, prediction:[3.6720376e-05], buyPrice:None, sellPrice:None, profit:None
# interation:181, intoTrade:False, prediction:[1.2788367e-11], buyPrice:None, sellPrice:None, profit:None
# interation:182, intoTrade:False, prediction:[5.1526385e-08], buyPrice:None, sellPrice:None, profit:None
# interation:183, intoTrade:False, prediction:[1.2147945e-10], buyPrice:None, sellPrice:None, profit:None
# interation:184, intoTrade:False, prediction:[2.480708e-05], buyPrice:None, sellPrice:None, profit:None
# interation:185, intoTrade:False, prediction:[1.4406129e-07], buyPrice:None, sellPrice:None, profit:None
# interation:186, intoTrade:False, prediction:[0.01139303], buyPrice:None, sellPrice:None, profit:None
# interation:187, intoTrade:False, prediction:[3.4463654e-05], buyPrice:None, sellPrice:None, profit:None
# interation:188, intoTrade:False, prediction:[3.2105155e-11], buyPrice:None, sellPrice:None, profit:None
# interation:189, intoTrade:False, prediction:[2.4783087e-10], buyPrice:None, sellPrice:None, profit:None
# interation:190, intoTrade:False, prediction:[2.3773662e-08], buyPrice:None, sellPrice:None, profit:None
# interation:191, intoTrade:False, prediction:[1.679682e-07], buyPrice:None, sellPrice:None, profit:None
# interation:192, intoTrade:False, prediction:[2.5046572e-07], buyPrice:None, sellPrice:None, profit:None
# interation:193, intoTrade:False, prediction:[7.8361495e-09], buyPrice:None, sellPrice:None, profit:None
# interation:194, intoTrade:False, prediction:[1.4105989e-09], buyPrice:None, sellPrice:None, profit:None
# interation:195, intoTrade:False, prediction:[1.2345603e-06], buyPrice:None, sellPrice:None, profit:None
# interation:196, intoTrade:False, prediction:[0.02872639], buyPrice:None, sellPrice:None, profit:None
# interation:197, intoTrade:False, prediction:[8.383621e-06], buyPrice:None, sellPrice:None, profit:None
# interation:199, intoTrade:True, prediction:[1.], buyPrice:[36851.58], sellPrice:[37700.87], profit:[849.29297]
# interation:201, intoTrade:True, prediction:[1.], buyPrice:[36182.94], sellPrice:[35620.26], profit:[-562.6797]
# interation:202, intoTrade:False, prediction:[4.6915215e-12], buyPrice:None, sellPrice:None, profit:None
# interation:203, intoTrade:False, prediction:[2.3994968e-12], buyPrice:None, sellPrice:None, profit:None
# interation:204, intoTrade:False, prediction:[7.859241e-10], buyPrice:None, sellPrice:None, profit:None
# interation:207, intoTrade:True, prediction:[0.99999565], buyPrice:[36473.38], sellPrice:[37514.496], profit:[1041.1172]
# interation:208, intoTrade:False, prediction:[6.244904e-08], buyPrice:None, sellPrice:None, profit:None
# interation:209, intoTrade:False, prediction:[8.1055544e-09], buyPrice:None, sellPrice:None, profit:None
# interation:210, intoTrade:False, prediction:[4.6421778e-10], buyPrice:None, sellPrice:None, profit:None
# interation:211, intoTrade:False, prediction:[3.8149386e-11], buyPrice:None, sellPrice:None, profit:None
# interation:212, intoTrade:False, prediction:[0.0001688], buyPrice:None, sellPrice:None, profit:None
# interation:213, intoTrade:False, prediction:[4.4138324e-06], buyPrice:None, sellPrice:None, profit:None
# interation:214, intoTrade:False, prediction:[3.6075992e-12], buyPrice:None, sellPrice:None, profit:None
# interation:215, intoTrade:False, prediction:[3.9946216e-11], buyPrice:None, sellPrice:None, profit:None
# interation:216, intoTrade:False, prediction:[6.7536976e-06], buyPrice:None, sellPrice:None, profit:None
# interation:217, intoTrade:False, prediction:[0.41150758], buyPrice:None, sellPrice:None, profit:None
# interation:218, intoTrade:False, prediction:[0.11930919], buyPrice:None, sellPrice:None, profit:None
# interation:219, intoTrade:False, prediction:[1.23085054e-17], buyPrice:None, sellPrice:None, profit:None
# interation:220, intoTrade:False, prediction:[4.1940618e-12], buyPrice:None, sellPrice:None, profit:None
# interation:221, intoTrade:False, prediction:[2.1864015e-07], buyPrice:None, sellPrice:None, profit:None
# interation:222, intoTrade:False, prediction:[5.040971e-09], buyPrice:None, sellPrice:None, profit:None
# interation:223, intoTrade:False, prediction:[5.72389e-07], buyPrice:None, sellPrice:None, profit:None
# interation:224, intoTrade:False, prediction:[1.4656114e-08], buyPrice:None, sellPrice:None, profit:None
# interation:225, intoTrade:False, prediction:[1.2113434e-16], buyPrice:None, sellPrice:None, profit:None
# interation:226, intoTrade:False, prediction:[1.0830702e-11], buyPrice:None, sellPrice:None, profit:None
# interation:227, intoTrade:False, prediction:[2.0496158e-07], buyPrice:None, sellPrice:None, profit:None
# interation:228, intoTrade:False, prediction:[2.3191007e-10], buyPrice:None, sellPrice:None, profit:None
# interation:229, intoTrade:False, prediction:[5.664173e-16], buyPrice:None, sellPrice:None, profit:None
# interation:230, intoTrade:False, prediction:[1.1172239e-16], buyPrice:None, sellPrice:None, profit:None
# interation:231, intoTrade:False, prediction:[5.1799834e-08], buyPrice:None, sellPrice:None, profit:None
# interation:232, intoTrade:False, prediction:[3.9186267e-12], buyPrice:None, sellPrice:None, profit:None
# interation:233, intoTrade:False, prediction:[2.4048312e-11], buyPrice:None, sellPrice:None, profit:None
# interation:234, intoTrade:False, prediction:[4.201432e-10], buyPrice:None, sellPrice:None, profit:None
# interation:235, intoTrade:False, prediction:[6.9330836e-06], buyPrice:None, sellPrice:None, profit:None
# interation:237, intoTrade:True, prediction:[0.99997157], buyPrice:[33458.08], sellPrice:[34516.09], profit:[1058.0117]
# interation:238, intoTrade:False, prediction:[1.7466041e-06], buyPrice:None, sellPrice:None, profit:None
# interation:239, intoTrade:False, prediction:[4.477954e-08], buyPrice:None, sellPrice:None, profit:None
# interation:241, intoTrade:True, prediction:[0.9999998], buyPrice:[33730.754], sellPrice:[34699.113], profit:[968.3594]
# interation:242, intoTrade:False, prediction:[0.09650268], buyPrice:None, sellPrice:None, profit:None
# interation:243, intoTrade:False, prediction:[1.2777238e-09], buyPrice:None, sellPrice:None, profit:None
# interation:244, intoTrade:False, prediction:[1.0061853e-08], buyPrice:None, sellPrice:None, profit:None
# interation:245, intoTrade:False, prediction:[2.7011454e-10], buyPrice:None, sellPrice:None, profit:None
# interation:246, intoTrade:False, prediction:[7.7199525e-11], buyPrice:None, sellPrice:None, profit:None
# interation:247, intoTrade:False, prediction:[1.2448083e-10], buyPrice:None, sellPrice:None, profit:None
# interation:248, intoTrade:False, prediction:[3.693906e-07], buyPrice:None, sellPrice:None, profit:None
# interation:249, intoTrade:False, prediction:[6.332265e-07], buyPrice:None, sellPrice:None, profit:None
# interation:250, intoTrade:False, prediction:[6.395721e-05], buyPrice:None, sellPrice:None, profit:None
# interation:252, intoTrade:True, prediction:[0.99967766], buyPrice:[32575.467], sellPrice:[31802.676], profit:[-772.791]
# interation:254, intoTrade:True, prediction:[1.], buyPrice:[31870.5], sellPrice:[31545.38], profit:[-325.11914]
# interation:255, intoTrade:False, prediction:[5.624742e-05], buyPrice:None, sellPrice:None, profit:None
# interation:258, intoTrade:True, prediction:[0.99999577], buyPrice:[31298.107], sellPrice:[31998.064], profit:[699.95703]
# interation:259, intoTrade:False, prediction:[0.00019238], buyPrice:None, sellPrice:None, profit:None
# interation:260, intoTrade:False, prediction:[2.1115906e-05], buyPrice:None, sellPrice:None, profit:None
# interation:261, intoTrade:False, prediction:[2.1085668e-06], buyPrice:None, sellPrice:None, profit:None
# interation:263, intoTrade:True, prediction:[1.], buyPrice:[30636.55], sellPrice:[30178.79], profit:[-457.76172]
# interation:264, intoTrade:False, prediction:[7.4784945e-15], buyPrice:None, sellPrice:None, profit:None
# interation:265, intoTrade:False, prediction:[1.3736047e-06], buyPrice:None, sellPrice:None, profit:None
# interation:266, intoTrade:False, prediction:[0.00120548], buyPrice:None, sellPrice:None, profit:None
# interation:267, intoTrade:False, prediction:[0.00139841], buyPrice:None, sellPrice:None, profit:None
# interation:268, intoTrade:False, prediction:[6.446962e-08], buyPrice:None, sellPrice:None, profit:None
# interation:269, intoTrade:False, prediction:[1.0320658e-06], buyPrice:None, sellPrice:None, profit:None
# interation:270, intoTrade:False, prediction:[2.3108893e-09], buyPrice:None, sellPrice:None, profit:None
# interation:271, intoTrade:False, prediction:[1.3499368e-06], buyPrice:None, sellPrice:None, profit:None
# interation:272, intoTrade:False, prediction:[3.4079775e-07], buyPrice:None, sellPrice:None, profit:None
# interation:273, intoTrade:False, prediction:[1.1821476e-07], buyPrice:None, sellPrice:None, profit:None
# interation:274, intoTrade:False, prediction:[0.00136165], buyPrice:None, sellPrice:None, profit:None
# interation:276, intoTrade:True, prediction:[0.99995846], buyPrice:[40133.062], sellPrice:[39623.156], profit:[-509.90625]
# interation:277, intoTrade:False, prediction:[2.052792e-06], buyPrice:None, sellPrice:None, profit:None
# interation:279, intoTrade:True, prediction:[0.999991], buyPrice:[38872.668], sellPrice:[39909.63], profit:[1036.9609]
# interation:280, intoTrade:False, prediction:[0.00013353], buyPrice:None, sellPrice:None, profit:None
# interation:281, intoTrade:False, prediction:[5.339702e-17], buyPrice:None, sellPrice:None, profit:None
# interation:282, intoTrade:False, prediction:[3.3153202e-09], buyPrice:None, sellPrice:None, profit:None
# interation:283, intoTrade:False, prediction:[9.400661e-11], buyPrice:None, sellPrice:None, profit:None
# interation:284, intoTrade:False, prediction:[0.07787241], buyPrice:None, sellPrice:None, profit:None
# interation:285, intoTrade:False, prediction:[0.00394985], buyPrice:None, sellPrice:None, profit:None
# interation:287, intoTrade:True, prediction:[0.9896537], buyPrice:[40470.67], sellPrice:[39736.863], profit:[-733.8086]
# interation:288, intoTrade:False, prediction:[8.140094e-05], buyPrice:None, sellPrice:None, profit:None
# interation:289, intoTrade:False, prediction:[9.0001384e-13], buyPrice:None, sellPrice:None, profit:None
# interation:290, intoTrade:False, prediction:[4.682417e-07], buyPrice:None, sellPrice:None, profit:None
# interation:291, intoTrade:False, prediction:[0.44019237], buyPrice:None, sellPrice:None, profit:None
# interation:292, intoTrade:False, prediction:[0.460439], buyPrice:None, sellPrice:None, profit:None
# interation:294, intoTrade:True, prediction:[1.], buyPrice:[45158.09], sellPrice:[44604.], profit:[-554.08984]
# interation:295, intoTrade:False, prediction:[2.5380148e-13], buyPrice:None, sellPrice:None, profit:None
# interation:296, intoTrade:False, prediction:[1.3117604e-11], buyPrice:None, sellPrice:None, profit:None
# interation:297, intoTrade:False, prediction:[1.8858195e-09], buyPrice:None, sellPrice:None, profit:None
# interation:299, intoTrade:True, prediction:[0.9974309], buyPrice:[46648.02], sellPrice:[47885.66], profit:[1237.6406]
# interation:300, intoTrade:False, prediction:[0.00011747], buyPrice:None, sellPrice:None, profit:None
# interation:301, intoTrade:False, prediction:[9.82937e-09], buyPrice:None, sellPrice:None, profit:None
# interation:302, intoTrade:False, prediction:[4.14732e-07], buyPrice:None, sellPrice:None, profit:None
# interation:303, intoTrade:False, prediction:[0.0655153], buyPrice:None, sellPrice:None, profit:None
# interation:304, intoTrade:False, prediction:[6.263764e-05], buyPrice:None, sellPrice:None, profit:None
# interation:305, intoTrade:False, prediction:[4.3608195e-15], buyPrice:None, sellPrice:None, profit:None
# interation:306, intoTrade:False, prediction:[7.429361e-11], buyPrice:None, sellPrice:None, profit:None
# interation:307, intoTrade:False, prediction:[3.0338936e-06], buyPrice:None, sellPrice:None, profit:None
# interation:308, intoTrade:False, prediction:[1.8141246e-07], buyPrice:None, sellPrice:None, profit:None
# interation:309, intoTrade:False, prediction:[0.2371755], buyPrice:None, sellPrice:None, profit:None
# interation:310, intoTrade:False, prediction:[0.00609237], buyPrice:None, sellPrice:None, profit:None
# interation:312, intoTrade:True, prediction:[0.99996823], buyPrice:[48201.777], sellPrice:[47669.285], profit:[-532.4922]
# interation:315, intoTrade:True, prediction:[0.9999992], buyPrice:[46954.137], sellPrice:[48158.43], profit:[1204.293]
# interation:316, intoTrade:False, prediction:[6.7211914e-08], buyPrice:None, sellPrice:None, profit:None
# interation:317, intoTrade:False, prediction:[6.8797074e-10], buyPrice:None, sellPrice:None, profit:None
# interation:318, intoTrade:False, prediction:[2.99056e-06], buyPrice:None, sellPrice:None, profit:None
# interation:320, intoTrade:True, prediction:[0.6510337], buyPrice:[31280.672], sellPrice:[30578.436], profit:[-702.2363]
# interation:321, intoTrade:False, prediction:[1.4700957e-09], buyPrice:None, sellPrice:None, profit:None
# interation:322, intoTrade:False, prediction:[2.639112e-05], buyPrice:None, sellPrice:None, profit:None
# interation:323, intoTrade:False, prediction:[3.7138705e-06], buyPrice:None, sellPrice:None, profit:None
# interation:324, intoTrade:False, prediction:[7.0187774e-08], buyPrice:None, sellPrice:None, profit:None
# interation:325, intoTrade:False, prediction:[2.5233192e-15], buyPrice:None, sellPrice:None, profit:None
# interation:326, intoTrade:False, prediction:[5.713092e-10], buyPrice:None, sellPrice:None, profit:None
# interation:327, intoTrade:False, prediction:[7.128141e-11], buyPrice:None, sellPrice:None, profit:None
# interation:328, intoTrade:False, prediction:[4.4163954e-17], buyPrice:None, sellPrice:None, profit:None
# interation:329, intoTrade:False, prediction:[4.9842646e-07], buyPrice:None, sellPrice:None, profit:None
# interation:330, intoTrade:False, prediction:[2.511819e-05], buyPrice:None, sellPrice:None, profit:None
# interation:331, intoTrade:False, prediction:[4.265146e-07], buyPrice:None, sellPrice:None, profit:None
# interation:333, intoTrade:True, prediction:[1.], buyPrice:[47423.9], sellPrice:[46712.12], profit:[-711.77734]
# interation:334, intoTrade:False, prediction:[9.630472e-08], buyPrice:None, sellPrice:None, profit:None
# interation:335, intoTrade:False, prediction:[5.909856e-06], buyPrice:None, sellPrice:None, profit:None
# interation:336, intoTrade:False, prediction:[2.1840034e-09], buyPrice:None, sellPrice:None, profit:None
# interation:337, intoTrade:False, prediction:[4.6886058e-07], buyPrice:None, sellPrice:None, profit:None
# interation:338, intoTrade:False, prediction:[4.5378172e-07], buyPrice:None, sellPrice:None, profit:None
# interation:339, intoTrade:False, prediction:[2.1837827e-09], buyPrice:None, sellPrice:None, profit:None
# interation:340, intoTrade:False, prediction:[3.4387872e-07], buyPrice:None, sellPrice:None, profit:None
# interation:341, intoTrade:False, prediction:[0.00644752], buyPrice:None, sellPrice:None, profit:None
# interation:344, intoTrade:True, prediction:[1.], buyPrice:[45183.22], sellPrice:[46600.21], profit:[1416.9922]
# interation:345, intoTrade:False, prediction:[2.628689e-09], buyPrice:None, sellPrice:None, profit:None
# interation:346, intoTrade:False, prediction:[1.5076601e-07], buyPrice:None, sellPrice:None, profit:None
# interation:347, intoTrade:False, prediction:[1.3714206e-08], buyPrice:None, sellPrice:None, profit:None
# interation:348, intoTrade:False, prediction:[3.7363486e-09], buyPrice:None, sellPrice:None, profit:None
# interation:349, intoTrade:False, prediction:[9.032146e-12], buyPrice:None, sellPrice:None, profit:None
# interation:350, intoTrade:False, prediction:[1.3675735e-07], buyPrice:None, sellPrice:None, profit:None
# interation:351, intoTrade:False, prediction:[3.0774126e-07], buyPrice:None, sellPrice:None, profit:None
# interation:352, intoTrade:False, prediction:[0.00129909], buyPrice:None, sellPrice:None, profit:None
# interation:353, intoTrade:False, prediction:[0.00413603], buyPrice:None, sellPrice:None, profit:None
# interation:354, intoTrade:False, prediction:[2.7547972e-06], buyPrice:None, sellPrice:None, profit:None
# interation:357, intoTrade:True, prediction:[0.9999998], buyPrice:[42763.17], sellPrice:[42056.633], profit:[-706.53906]
# interation:358, intoTrade:False, prediction:[1.1433614e-05], buyPrice:None, sellPrice:None, profit:None
# interation:359, intoTrade:False, prediction:[0.12776345], buyPrice:None, sellPrice:None, profit:None
# interation:360, intoTrade:False, prediction:[2.664956e-09], buyPrice:None, sellPrice:None, profit:None
# interation:361, intoTrade:False, prediction:[1.2430086e-08], buyPrice:None, sellPrice:None, profit:None
# interation:362, intoTrade:False, prediction:[0.00051163], buyPrice:None, sellPrice:None, profit:None
# interation:363, intoTrade:False, prediction:[1.0068217e-05], buyPrice:None, sellPrice:None, profit:None
# interation:364, intoTrade:False, prediction:[4.7007105e-16], buyPrice:None, sellPrice:None, profit:None
# interation:365, intoTrade:False, prediction:[2.0999219e-10], buyPrice:None, sellPrice:None, profit:None
# interation:366, intoTrade:False, prediction:[2.178609e-11], buyPrice:None, sellPrice:None, profit:None
# interation:367, intoTrade:False, prediction:[2.2022582e-09], buyPrice:None, sellPrice:None, profit:None
# interation:368, intoTrade:False, prediction:[1.5530631e-08], buyPrice:None, sellPrice:None, profit:None
# interation:369, intoTrade:False, prediction:[2.3391653e-08], buyPrice:None, sellPrice:None, profit:None
# interation:371, intoTrade:True, prediction:[0.99999964], buyPrice:[47810.016], sellPrice:[49348.77], profit:[1538.7539]
# interation:373, intoTrade:True, prediction:[0.999973], buyPrice:[50694.555], sellPrice:[52781.195], profit:[2086.6406]
# interation:375, intoTrade:True, prediction:[1.], buyPrice:[54340.03], sellPrice:[53786.14], profit:[-553.8906]
# interation:378, intoTrade:True, prediction:[0.9999873], buyPrice:[54006.473], sellPrice:[55243.137], profit:[1236.6641]
# interation:379, intoTrade:False, prediction:[1.1979367e-06], buyPrice:None, sellPrice:None, profit:None
# interation:380, intoTrade:False, prediction:[3.091264e-07], buyPrice:None, sellPrice:None, profit:None
# interation:381, intoTrade:False, prediction:[9.979602e-06], buyPrice:None, sellPrice:None, profit:None
# interation:382, intoTrade:False, prediction:[0.00664715], buyPrice:None, sellPrice:None, profit:None
# interation:383, intoTrade:False, prediction:[7.870971e-14], buyPrice:None, sellPrice:None, profit:None
# interation:384, intoTrade:False, prediction:[2.2131248e-14], buyPrice:None, sellPrice:None, profit:None
# interation:385, intoTrade:False, prediction:[1.2295867e-08], buyPrice:None, sellPrice:None, profit:None
# interation:386, intoTrade:False, prediction:[1.1366525e-05], buyPrice:None, sellPrice:None, profit:None
# interation:387, intoTrade:False, prediction:[6.193269e-12], buyPrice:None, sellPrice:None, profit:None
# interation:388, intoTrade:False, prediction:[7.934192e-09], buyPrice:None, sellPrice:None, profit:None
# interation:389, intoTrade:False, prediction:[1.4304358e-05], buyPrice:None, sellPrice:None, profit:None
# interation:390, intoTrade:False, prediction:[0.0469171], buyPrice:None, sellPrice:None, profit:None
# interation:391, intoTrade:False, prediction:[2.6802535e-13], buyPrice:None, sellPrice:None, profit:None
# interation:392, intoTrade:False, prediction:[1.8015387e-17], buyPrice:None, sellPrice:None, profit:None
# interation:393, intoTrade:False, prediction:[1.8979067e-10], buyPrice:None, sellPrice:None, profit:None

# %%
print(total_profit)
# Out:
# [3018.5195]
